# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
api_key ='0e995274771545fde6001e68702cf6db'
from fredapi import Fred
fred = Fred(api_key=api_key)
df = {}
df['SPX'] = fred.get_series('SP500')
df['10YR'] = fred.get_series('DGS10')
data = pd.DataFrame(df)

data.tail()
# Out:
#                 SPX  10YR
# 2019-08-12  2883.75  1.65
# 2019-08-13  2926.32  1.68
# 2019-08-14  2840.60  1.59
# 2019-08-15  2847.60  1.52
# 2019-08-16  2888.68   NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15034 entries, 1962-01-02 to 2019-08-16
# Freq: B
# Data columns (total 2 columns):
# SPX     2518 non-null float64
# 10YR    14391 non-null float64
# dtypes: float64(2)
# memory usage: 352.4 KB

# %%
data.dropna(inplace=True)

# %%
ax = data.SPX.plot() 
ax2 = ax.twinx()
ax2.plot(data['10YR'], color='orange')
ax.legend()
ax2.legend()
